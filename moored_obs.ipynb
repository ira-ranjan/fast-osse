# %%
import obs_to_obs_seq_in as obsin
import moored_obs_generator as obsgen
import datetime as dt

# %%
taominus1 = obsgen.MooredObs(-1,140,8,80,2,"height (m)",dt.datetime(2017,10,3,12),dt.datetime(2018,7,3,12),0.001,5)
taominus2 = obsgen.MooredObs(-2,140,8,80,2,"height (m)",dt.datetime(2017,10,3,12),dt.datetime(2018,7,3,12),0.001,5)
tao0 = obsgen.MooredObs(0,140,8,80,2,"height (m)",dt.datetime(2017,10,3,12),dt.datetime(2018,7,3,12),0.001,5)
taoplus1 = obsgen.MooredObs(1,140,8,80,2,"height (m)",dt.datetime(2017,10,3,12),dt.datetime(2018,7,3,12),0.001,5)
taoplus2 = obsgen.MooredObs(21,140,8,80,2,"height (m)",dt.datetime(2017,10,3,12),dt.datetime(2018,7,3,12),0.001,5)

# %%
taominus1.metadata
# Out:
# [{'longitude': -1.0,
#   'latitude': 140.0,
#   'vertical': 8.0,
#   'vert_unit': 'height (m)',
#   'type': 'U_VELOCITY',
#   'metadata': [],
#   'external_FO': [],
#   'seconds': 43200,
#   'days': 152216,
#   'time': '12:00:00',
#   'obs_err_var': 0.001},
#  {'longitude': -1.0,
#   'latitude': 140.0,
#   'vertical': 8.0,
#   'vert_unit': 'height (m)',
#   'type': 'V_VELOCITY',
#   'metadata': [],
#   'external_FO': [],
#   'seconds': 43200,
#   'days': 152216,
#   'time': '12:00:00',
#   'obs_err_var': 0.001},
#  {'longitude': -1.0,
#   'latitude': 140.0,
#   'vertical': 8.0,
#   'vert_unit': 'height (m)',
#   'type': 'SEA SURFACE HEIGHT',
#   'metadata': [],
#   'external_FO': [],
#   'seconds': 43200,
#   'days': 152216,
#   'time': '12:00:00',
#   'obs_err_var': 0.001},
#  {'longitude': -1.0,
#   'latitude': 140.0,
#   'vertical': 10.0,
#   'vert_unit': 'height (m)',
#   'type': 'U_VELOCITY',
#   'metadata': [],
#   'external_FO': [],
#   'seconds': 43200,
#   'days': 152216,
# ...

# %%
obs_seq = obsin.create_obs_seq_in()

# %%
obsin.add_list_to_df(taominus1.metadata, obs_seq)
obsin.add_list_to_df(taominus2.metadata, obs_seq)
obsin.add_list_to_df(tao0.metadata, obs_seq)
obsin.add_list_to_df(taoplus1.metadata, obs_seq)
obsin.add_list_to_df(taoplus2.metadata, obs_seq)
# Out:
# /Users/iranjan/fast-osse/obs_to_obs_seq_in.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)

# %%
print(obs_seq.df)
# Out:
#            obs_num                linked_list  longitude  latitude  vertical  \
# 0                1  -1          2          -1       -1.0     140.0       8.0
# 1                2  1           3          -1       -1.0     140.0       8.0
# 2                3  2           4          -1       -1.0     140.0       8.0
# 3                4  3           5          -1       -1.0     140.0      10.0
# 4                5  4           6          -1       -1.0     140.0      10.0
# ...            ...                        ...        ...       ...       ...
# 41278120  41278121  41278120    41278122   -1        1.0     140.0      74.0
# 41278121  41278122  41278121    41278123   -1        1.0     140.0      74.0
# 41278122  41278123  41278122    41278124   -1        1.0     140.0      76.0
# 41278123  41278124  41278123    41278125   -1        1.0     140.0      76.0
# 41278124  41278125  41278124    -1         -1        1.0     140.0      76.0
#
# ...

# %%
obs_seq.df.tail(15)
# Out:
#            obs_num                linked_list  longitude  latitude  vertical  \
# 41278110  41278111  41278110    41278112   -1        1.0     140.0      68.0
# 41278111  41278112  41278111    41278113   -1        1.0     140.0      68.0
# 41278112  41278113  41278112    41278114   -1        1.0     140.0      68.0
# 41278113  41278114  41278113    41278115   -1        1.0     140.0      70.0
# 41278114  41278115  41278114    41278116   -1        1.0     140.0      70.0
# 41278115  41278116  41278115    41278117   -1        1.0     140.0      70.0
# 41278116  41278117  41278116    41278118   -1        1.0     140.0      72.0
# 41278117  41278118  41278117    41278119   -1        1.0     140.0      72.0
# 41278118  41278119  41278118    41278120   -1        1.0     140.0      72.0
# 41278119  41278120  41278119    41278121   -1        1.0     140.0      74.0
# 41278120  41278121  41278120    41278122   -1        1.0     140.0      74.0
# ...

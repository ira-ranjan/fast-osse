# %%
import obs_to_obs_seq_in as obsin
import moored_obs_generator as obsgen
import datetime as dt

# %%
# obs_err_var set to 0.01 at the moment

# %%
# Creates an empty obs_sequence object

obs_seq = obsin.create_obs_seq_in()

# %%
start_year = 2015
start_month = 1
start_date = 1
start_time = 12
end_year = 2015
end_month = 1
end_date = 3
end_time = 12

# %%
# Creates MooredObs objects for each of the 5 ADCP-equipped TAO moorings at 140W

taominus1 = obsgen.MooredObs(obs_seq, 220,-1,30,250,5,"height (m)",dt.datetime(start_year,start_month,start_date,start_time),dt.datetime(end_year,end_month,end_date,end_time),0.001,dt.timedelta(hours=3))
taominus2 = obsgen.MooredObs(obs_seq,220,-2,30,250,5,"height (m)",dt.datetime(start_year,start_month,start_date,start_time),dt.datetime(end_year,end_month,end_date,end_time),0.001,dt.timedelta(hours=3))
tao0 = obsgen.MooredObs(obs_seq,220,0,30,250,5,"height (m)",dt.datetime(start_year,start_month,start_date,start_time),dt.datetime(end_year,end_month,end_date,end_time),0.001,dt.timedelta(hours=3))
taoplus1 = obsgen.MooredObs(obs_seq,220,1,30,250,5,"height (m)",dt.datetime(start_year,start_month,start_date,start_time),dt.datetime(end_year,end_month,end_date,end_time),0.001,dt.timedelta(hours=3))
taoplus2 = obsgen.MooredObs(obs_seq,220,2,30,250,5,"height (m)",dt.datetime(start_year,start_month,start_date,start_time),dt.datetime(end_year,end_month,end_date,end_time),0.001,dt.timedelta(hours=3))
# Out:
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)

# %%
# Creates MooredObs objects for each of the ADCP-equipped wavegliders to be deployed

adcp1 = obsgen.MooredObs(obs_seq,219,2,8,80,2,"height (m)",dt.datetime(start_year,start_month,start_date,start_time),dt.datetime(end_year,end_month,end_date,end_time),0.001,dt.timedelta(hours=3))
adcp2 = obsgen.MooredObs(obs_seq,219,0,8,80,2,"height (m)",dt.datetime(start_year,start_month,start_date,start_time),dt.datetime(end_year,end_month,end_date,end_time),0.001,dt.timedelta(hours=3))
adcp3 = obsgen.MooredObs(obs_seq,221,2,8,80,2,"height (m)",dt.datetime(start_year,start_month,start_date,start_time),dt.datetime(end_year,end_month,end_date,end_time),0.001,dt.timedelta(hours=3))
adcp4 = obsgen.MooredObs(obs_seq,221,0,8,80,2,"height (m)",dt.datetime(start_year,start_month,start_date,start_time),dt.datetime(end_year,end_month,end_date,end_time),0.001,dt.timedelta(hours=3))

# %%
print(obs_seq.df)
# Out:
#        obs_num                linked_list  longitude  latitude  vertical  \
# 0            1  -1          2          -1      220.0      -1.0      30.0
# 1            2  1           3          -1      220.0      -1.0      30.0
# 2            3  2           4          -1      220.0      -1.0      35.0
# 3            4  3           5          -1      220.0      -1.0      35.0
# 4            5  4           6          -1      220.0      -1.0      40.0
# ...        ...                        ...        ...       ...       ...
# 12677    12678  12677       12679      -1      221.0       0.0      76.0
# 12678    12679  12678       12680      -1      221.0       0.0      78.0
# 12679    12680  12679       12681      -1      221.0       0.0      78.0
# 12680    12681  12680       12682      -1      221.0       0.0      80.0
# 12681    12682  12681       -1         -1      221.0       0.0      80.0
#
#         vert_unit                        type metadata external_FO seconds  \
# 0      height (m)  GLIDER_U_CURRENT_COMPONENT       []          []   43200
# 1      height (m)  GLIDER_V_CURRENT_COMPONENT       []          []   43200
# 2      height (m)  GLIDER_U_CURRENT_COMPONENT       []          []   43200
# 3      height (m)  GLIDER_V_CURRENT_COMPONENT       []          []   43200
# 4      height (m)  GLIDER_U_CURRENT_COMPONENT       []          []   43200
# ...           ...                         ...      ...         ...     ...
# 12677  height (m)  GLIDER_V_CURRENT_COMPONENT       []          []   43200
# 12678  height (m)  GLIDER_U_CURRENT_COMPONENT       []          []   43200
# 12679  height (m)  GLIDER_V_CURRENT_COMPONENT       []          []   43200
# 12680  height (m)  GLIDER_U_CURRENT_COMPONENT       []          []   43200
# 12681  height (m)  GLIDER_V_CURRENT_COMPONENT       []          []   43200
#
#          days                time  obs_err_var
# 0      151210 2015-01-01 12:00:00        0.001
# 1      151210 2015-01-01 12:00:00        0.001
# 2      151210 2015-01-01 12:00:00        0.001
# 3      151210 2015-01-01 12:00:00        0.001
# 4      151210 2015-01-01 12:00:00        0.001
# ...       ...                 ...          ...
# 12677  151212 2015-01-03 12:00:00        0.001
# 12678  151212 2015-01-03 12:00:00        0.001
# 12679  151212 2015-01-03 12:00:00        0.001
# 12680  151212 2015-01-03 12:00:00        0.001
# 12681  151212 2015-01-03 12:00:00        0.001
#
# [12682 rows x 13 columns]

# %%
obsin.split_obs_seq_by_time(obs_seq, "/glade/derecho/scratch/iranjan/archive/eep-slice-test/split", "EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.")
# Out:
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-001-12
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-001-15
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-001-18
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-001-21
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-001-24
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-002-03
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-002-06
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-002-09
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-002-12
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-002-15
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-002-18
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-002-21
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-002-24
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-003-03
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-003-06
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-003-09
# EEP_MITgcm185Lvgrid_Whitt2026hgrid.mom6.h.z.2015-01-003-12
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /glade/work/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)

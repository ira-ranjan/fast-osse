# %%
# obs_err_var set to 0.01 at the moment

# %%
import obs_to_obs_seq_in as obsin
import moored_obs_generator as obsgen
import datetime as dt

# %%
# Creates an empty obs_sequence object

obs_seq = obsin.create_obs_seq_in()

# %%
# Creates MooredObs objects for each of the 5 ADCP-equipped TAO moorings at 140W

taominus1 = obsgen.MooredObs(obs_seq, 220,-1,30,250,5,"height (m)",dt.datetime(2015,8,30,12),dt.datetime(2015,9,1,12),0.001,dt.timedelta(hours=3))
taominus2 = obsgen.MooredObs(obs_seq,220,-2,30,250,5,"height (m)",dt.datetime(2015,8,30,12),dt.datetime(2015,9,1,12),0.001,dt.timedelta(hours=3))
tao0 = obsgen.MooredObs(obs_seq,220,0,30,250,5,"height (m)",dt.datetime(2015,8,30,12),dt.datetime(2015,9,1,12),0.001,dt.timedelta(hours=3))
taoplus1 = obsgen.MooredObs(obs_seq,220,1,30,250,5,"height (m)",dt.datetime(2015,8,30,12),dt.datetime(2015,9,1,12),0.001,dt.timedelta(hours=3))
taoplus2 = obsgen.MooredObs(obs_seq,220,2,30,250,5,"height (m)",dt.datetime(2015,8,30,12),dt.datetime(2015,9,1,12),0.001,dt.timedelta(hours=3))
# Out:
# /Users/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)

# %%
# Creates MooredObs objects for each of the ADCP-equipped wavegliders to be deployed

adcp1 = obsgen.MooredObs(obs_seq,219,2,8,80,2,"height (m)",dt.datetime(2015,8,30,12),dt.datetime(2015,9,1,12),0.001,dt.timedelta(hours=3))
adcp2 = obsgen.MooredObs(obs_seq,219,0,8,80,2,"height (m)",dt.datetime(2015,8,30,12),dt.datetime(2015,9,1,12),0.001,dt.timedelta(hours=3))
adcp3 = obsgen.MooredObs(obs_seq,221,2,8,80,2,"height (m)",dt.datetime(2015,8,30,12),dt.datetime(2015,9,1,12),0.001,dt.timedelta(hours=3))
adcp4 = obsgen.MooredObs(obs_seq,221,0,8,80,2,"height (m)",dt.datetime(2015,8,30,12),dt.datetime(2015,9,1,12),0.001,dt.timedelta(hours=3))

# %%
print(obs_seq.df)
# Out:
#        obs_num                linked_list  longitude  latitude  vertical  \
# 0            1  -1          2          -1      220.0      -1.0      30.0
# 1            2  1           3          -1      220.0      -1.0      30.0
# 2            3  2           4          -1      220.0      -1.0      30.0
# 3            4  3           5          -1      220.0      -1.0      35.0
# 4            5  4           6          -1      220.0      -1.0      35.0
# ...        ...                        ...        ...       ...       ...
# 19834    19835  19834       19836      -1      221.0       0.0      78.0
# 19835    19836  19835       19837      -1      221.0       0.0      78.0
# 19836    19837  19836       19838      -1      221.0       0.0      80.0
# 19837    19838  19837       19839      -1      221.0       0.0      80.0
# 19838    19839  19838       -1         -1      221.0       0.0      80.0
#
#         vert_unit                        type metadata external_FO seconds  \
# ...

# %%
obsin.split_obs_seq_by_time(obs_seq)
# Out:
# /Users/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /Users/iranjan/fast-osse/obs_to_obs_seq_in.py:115: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# ...

# %%
obs_seq.df.columns
# Out:
# Index(['obs_num', 'linked_list', 'longitude', 'latitude', 'vertical',
#        'vert_unit', 'type', 'metadata', 'external_FO', 'seconds', 'days',
#        'time', 'obs_err_var'],
#       dtype='object')

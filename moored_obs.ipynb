# %%
# obs_err_var set to 0.01 at the moment

# %%
import obs_to_obs_seq_in as obsin
import moored_obs_generator as obsgen
import datetime as dt

# %%
# Creates MooredObs objects for each of the 5 ADCP-equipped TAO moorings at 140W

taominus1 = obsgen.MooredObs(-1,140,30,250,5,"height (m)",dt.datetime(2017,10,3,12),dt.datetime(2017,10,6,12),0.001,5)
taominus2 = obsgen.MooredObs(-2,140,30,250,5,"height (m)",dt.datetime(2017,10,3,12),dt.datetime(2017,10,6,12),0.001,5)
tao0 = obsgen.MooredObs(0,140,30,250,5,"height (m)",dt.datetime(2017,10,3,12),dt.datetime(2017,10,6,12),0.001,5)
taoplus1 = obsgen.MooredObs(1,140,30,250,5,"height (m)",dt.datetime(2017,10,3,12),dt.datetime(2017,10,6,12),0.001,5)
taoplus2 = obsgen.MooredObs(21,140,30,250,5,"height (m)",dt.datetime(2017,10,3,12),dt.datetime(2017,10,6,12),0.001,5)

# %%
# Creates an empty obs_sequence object

obs_seq = obsin.create_obs_seq_in()

# %%
obsin.add_list_to_df(taominus1.metadata, obs_seq)
obsin.add_list_to_df(taominus2.metadata, obs_seq)
obsin.add_list_to_df(tao0.metadata, obs_seq)
obsin.add_list_to_df(taoplus1.metadata, obs_seq)
obsin.add_list_to_df(taoplus2.metadata, obs_seq)
# Out:
# /Users/iranjan/fast-osse/obs_to_obs_seq_in.py:118: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)

# %%
print(obs_seq.df)
# Out:
#         obs_num                linked_list  longitude  latitude  vertical  \
# 0             1  -1          2          -1       -1.0     140.0      30.0
# 1             2  1           3          -1       -1.0     140.0      30.0
# 2             3  2           4          -1       -1.0     140.0      30.0
# 3             4  3           5          -1       -1.0     140.0      35.0
# 4             5  4           6          -1       -1.0     140.0      35.0
# ...         ...                        ...        ...       ...       ...
# 583870   583871  583870      583872     -1       21.0     140.0     245.0
# 583871   583872  583871      583873     -1       21.0     140.0     245.0
# 583872   583873  583872      583874     -1       21.0     140.0     250.0
# 583873   583874  583873      583875     -1       21.0     140.0     250.0
# 583874   583875  583874      -1         -1       21.0     140.0     250.0
#
#          vert_unit                type metadata external_FO seconds    days  \
# ...

# %%
obsin.split_obs_seq_and_write(obs_seq, 'days')
# Out:
# /Users/iranjan/fast-osse/obs_to_obs_seq_in.py:118: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# /Users/iranjan/fast-osse/obs_to_obs_seq_in.py:118: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   obs_seq.df = pd.concat([obs_seq.df, df_new], ignore_index=True)
# ...
